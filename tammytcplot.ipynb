# %%
# need to redo: file 7 (6), 12 (11)
# just do single-file. on 10/25 12PM as the next file to take tomorrow. Will do!

# %%
# hurricane tammy cyclone plots, we duplicate this plot until we get a coherent animation!

import matplotlib.pyplot as plt  # plotting library
import numpy as np  # numerical library
import xarray as xr  # netCDF library
import cartopy  # Map projections libary
import cartopy.crs as ccrs  # Projections list 

ds = xr.open_dataset(r'/Users/juliencheung/Documents/GitHub/Y1CyclonesSummerProject/data/tammy29.nc')
ds

u = ds.u10.sel(valid_time="2023-10-25T12:00:00", method='nearest').load()
v = ds.v10.sel(valid_time="2023-10-25T12:00:00", method='nearest').load()

ax = plt.axes(projection=ccrs.PlateCarree())  # note that I changed the map projection
qv = ax.quiver(u.longitude, u.latitude, u, v, transform=ccrs.PlateCarree())
ax.coastlines(color='grey');
